# %% [markdown]
# <a href="https://colab.research.google.com/github/said0717xx/week1lab/blob/main/week%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# scores = [72, 85, 90,68, 88]
# print "Scores:", scores)
#
#
# average = sum(scores) / len(scores)
# print ("Average score:", average)
#
#
# highest_score = max(scores)
# print("Highest: ", highest_score)lowest_score = min(scores)
# print("Lowest", lowest _score)
#
#
# Scores: [72, 85, 90, 68, 88]
# Average score: 80.6
# Highest: 90
# Lowest 68

# %% [markdown]
# # New section
